# %%
from data_processing import load_data
import matplotlib.pyplot as plt
import torchvision.transforms as T
import tqdm

# %%
trainloader, testloader = load_data(1)
image = []
label = []

# %%
i = 0
image = []
label = []
for inputs, targets in tqdm.tqdm(trainloader):
    image.append(inputs)
    label.append(targets)
    i+=1
    if i==10:
        break
# Out:
#   2%|▏         | 9/543 [00:13<12:55,  1.45s/it]

# %%
for i in range(10):
    plt.imshow(T.ToPILImage()(inputs[0]))
    plt.title(targets[0])
    plt.show()
