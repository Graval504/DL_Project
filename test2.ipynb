# %%
from data_processing import load_data
import matplotlib.pyplot as plt
import torchvision.transforms as T
import tqdm

# %%
trainloader, testloader = load_data(2)
image = []
label = []

# %%
i = 0
image = []
label = []
for inputs, targets in tqdm.tqdm(trainloader):
    image.append(inputs)
    label.append(targets)
    i+=1
    if i==20:
        break
# Out:
#   7%|▋         | 19/271 [00:04<01:03,  3.99it/s]

# %%
len(image)
# Out:
# 20

# %%
for i in range(10):
    plt.subplot(121)
    plt.imshow(T.ToPILImage()(image[i][0]))
    plt.title(label[i][0])
    plt.subplot(122)
    plt.imshow(T.ToPILImage()(image[i][1]))
    plt.title(label[i][1])
    plt.show()
